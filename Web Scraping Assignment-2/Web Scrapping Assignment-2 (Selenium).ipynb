# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
#Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
#have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
#jobs data.
driver=webdriver.Chrome()
driver.get('https://www.shine.com/new/job-search')
job_title=driver.find_element(By.CLASS_NAME,"form-control")
job_title.send_keys('Data Analysis')
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div/div/div[1]/div[1]/div/div[2]/div/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys('Bangalore')
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div/div/div[1]/div[1]/div/div[2]/div/div/form/div/div[2]/div/button")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
exp_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location[0:10]:
    location=i.text
    job_location.append(location)
    
company=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company[0:10]:
    company=i.text
    company_name.append(company)
    
experience=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience[0:10]:
    experience=i.text
    exp_required.append(experience)

# %%
##Q-4  Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
#Brand
#ProductDescription
#Price

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/")

# %%
glasses=driver.find_element(By.CLASS_NAME,'_3704LK')
glasses.send_keys('sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search.click()

# %%
brand=[]
product_description=[]
price=[]
Brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in Brand[0:35]:
    Brand=i.text
    brand.append(Brand)
    
Product_description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in Product_description[0:35]:
    Product_description=i.text
    product_description.append(Product_description)

Price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in Price[0:35]:
    Price=i.text
    price.append(Price)

import pandas as pd
df1=pd.DataFrame({'Brand':brand,'Product_description':product_description,'Price':price})
df1
# Out:
#             Brand                                Product_description   Price
# 0    Singco India          UV Protection Rectangular Sunglasses (55)    ₹502
# 1   VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)    ₹883
# 2            SRPM             UV Protection Wayfarer Sunglasses (50)    ₹204
# 3          PIRASO           UV Protection Clubmaster Sunglasses (54)    ₹239
# 4       Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...    ₹179
# 5       Elligator   UV Protection, Mirrored Wayfarer Sunglasses (54)    ₹199
# 6       Rich Club                   Mirrored Aviator Sunglasses (58)    ₹495
# 7       ROYAL SON   UV Protection Rectangular Sunglasses (Free Size)    ₹379
# 8        Fastrack             UV Protection Wayfarer Sunglasses (58)    ₹629
# 9        Fastrack  by Lenskart Polarized, UV Protection Round Sun...    ₹769
# 10  VINCENT CHASE     Polarized, UV Protection Round Sunglasses (48)    ₹883
# ...

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]/span")
search.click()

# %%
brand=[]
product_description=[]
price=[]

# %%
Brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in Brand:
    Brand=i.text
    brand.append(Brand)

Product_description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in Product_description:
    Product_description=i.text
    product_description.append(Product_description)

Price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in Price:
    Price=i.text
    price.append(Price)
import pandas as pd
df1=pd.DataFrame({'Brand':brand,'Product_description':product_description,'Price':price})
df1
# Out:
#              Brand                                Product_description   Price
# 0     Singco India          UV Protection Rectangular Sunglasses (55)    ₹502
# 1    VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)    ₹883
# 2             SRPM             UV Protection Wayfarer Sunglasses (50)    ₹204
# 3           PIRASO           UV Protection Clubmaster Sunglasses (54)    ₹239
# 4        Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...    ₹179
# ..             ...                                                ...     ...
# 70   VINCENT CHASE  by Lenskart Polarized, UV Protection Wayfarer ...    ₹699
# 71  RESIST EYEWEAR  Polarized, Riding Glasses, UV Protection Wayfa...  ₹1,312
# 72            IDEE             UV Protection Wayfarer Sunglasses (50)  ₹1,059
# 73         ROADWAY  UV Protection Retro Square Sunglasses (Free Size)    ₹222
# 74          PIRASO            UV Protection Butterfly Sunglasses (65)    ₹392
#
# [75 rows x 3 columns]

# %%
dataframe=[df,df1]
result=pd.concat(dataframe)
result
# Out:
#              Brand                                Product_description   Price
# 0     Singco India          UV Protection Rectangular Sunglasses (55)    ₹502
# 1        ROYAL SON                   Mirrored Aviator Sunglasses (58)    ₹379
# 2             SRPM             UV Protection Wayfarer Sunglasses (50)    ₹204
# 3           PIRASO           UV Protection Clubmaster Sunglasses (54)    ₹239
# 4        Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...    ₹179
# ..             ...                                                ...     ...
# 70   VINCENT CHASE  by Lenskart Polarized, UV Protection Wayfarer ...    ₹699
# 71  RESIST EYEWEAR  Polarized, Riding Glasses, UV Protection Wayfa...  ₹1,312
# 72            IDEE             UV Protection Wayfarer Sunglasses (50)  ₹1,059
# 73         ROADWAY  UV Protection Retro Square Sunglasses (Free Size)    ₹222
# 74          PIRASO            UV Protection Butterfly Sunglasses (65)    ₹392
#
# [111 rows x 3 columns]

# %%
#Q-5)Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
#https://www.flipkart.com/apple-iphone-11-black-64-gb/productreviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market
#place=FLIPKART

# %%
driver=webdriver.Chrome()
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/p/itm4e5041ba101fd")

# %%
rating=[]
review_summary=[]
full_review=[]

# %%
Rating=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in Rating[0:100]:
    Rating=i.text
    rating.append(Rating)
    
Review_summary=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in Review_summary[0:100]:
    Review_summary=i.text
    review_summary.append(Review_summary)
    
Full_review=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in Full_review[0:100]:
    Full_review=i.text
    full_review.append(Full_review)
import pandas as pd
df=pd.DataFrame({'Rating':rating,'Review_summary':review_summary,'Full_review':full_review})
df
# Out:
#     Rating  Review_summary                                        Full_review
# 0        5  Classy product                                       Photos super
# 1        5  Classy product  Camera is awesome\nBest battery backup\nA perf...
# 2        5        Terrific                                     Very very good
# 3
# 4
# ..     ...             ...                                                ...
# 195
# 196
# 197
# 198
# 199
#
# [200 rows x 3 columns]

# %%
#Q-6)Scrape data for first 100 sneakers you find whenyou visit flipkart.com and search for “sneakers” inthe
# search field
driver=webdriver.Chrome()
driver.get("https://www.flipkart.com/")

# %%
shoes=driver.find_element(By.CLASS_NAME,'_3704LK')
shoes.send_keys('Sneakers')

# %%
search=driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search.click()

# %%
brand=[]
product_description=[]
price=[]

# %%
Brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in Brand[0:20]:
    Brand=i.text
    brand.append(Brand)
    
Product_description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in Product_description[0:20]:
    Product_description=i.text
    product_description.append(Product_description)
    
Price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in Price[0:20]:
    Price=i.text
    price.append(Price)

# %%
import pandas as pd
df=pd.DataFrame({'Brand':brand,'Product_description':product_description,'Price':price})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2176\4198290597.py in <module>
#       1 import pandas as pd
# ----> 2 df=pd.DataFrame({'Brand':brand,'Product_description':product_description,'Price':price})
#       3 df
#
# C:\ProgramData\Anaconda33\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda33\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...
